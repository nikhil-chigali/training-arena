# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# Import python's built-in regular expression library
import re
import anthropic


client = anthropic.Anthropic()
MODEL_NAME = "claude-haiku-4-5"

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake,
# Dancing through electric dreams—
# Steel hearts beat as one.

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake
# Circuits hum their ancient song
# Steel dreams march forward

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# That's one of sports' most debated questions, with no definitive answer. The most common candidates are:
#
# **Michael Jordan** - Often cited as #1 for his 6 championships, competitive drive, and dominance in the 1990s
#
# **LeBron James** - Longevity, all-around skills, and sustained excellence across multiple decades
#
# **Kareem Abdul-Jabbar** - All-time scoring leader for decades, incredible consistency
#
# **Magic Johnson & Larry Bird** - Revolutionized the game in the 1980s
#
# **Wilt Chamberlain & Bill Russell** - Dominated their eras, though different competition levels
#
# The "best" depends on what you value—peak performance, longevity, championships, era-adjusted stats, or all-around game. Most basketball analysts lean toward Jordan or LeBron, but reasonable people disagree based on different criteria and eras they watched.
#
# Who do you think makes the strongest case?

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# I'd go with Michael Jordan.
#
# The case is pretty straightforward: six championships, five MVPs, 10 scoring titles, and he did it in an era where defense was genuinely physical. He had the killer instinct in crucial moments that's hard to match. The Finals performances especially—he showed up when it mattered most.
#
# LeBron has the longevity argument and is probably more complete overall. Kareem has the scoring record (until recently). But Jordan's peak was higher, and he won when it counted.
#
# That said, I'm genuinely uncertain about this. If you asked me in five years after seeing how LeBron's legacy settles, or how Luka develops, I might answer differently. The "best ever" question depends a lot on what you weight—peak vs. longevity, era-adjusted stats vs. raw numbers, championships vs. individual dominance.
#
# But if forced to choose *one* right now? Jordan.
#
# Who would you pick?

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should change
SYSTEM_PROMPT = "You are a helpful Spanish assistant. You only respond in Spanish language."

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. ¿Cómo estás tú? ¿En qué puedo ayudarte hoy?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)
# Out:
# The grading function in this exercise is looking for any answer that includes the word "hola".
# Ask Claude to reply in Spanish like you would when speaking with a human. It's that simple!

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be? Respond only with the player's name. No preamble."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)
# Out:
# The grading function in this exercise is looking for EXACTLY "Michael Jordan".
# How would you ask another human to do this? Reply with no other words? Reply with only the name and nothing else? There are several ways to approach this answer.

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "Give me a big paragraph about Nuclear power. Be very elaborative and over 1000 words."

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# # Nuclear Power: A Comprehensive Exploration of Energy's Most Controversial Source
#
# Nuclear power stands as one of the most significant and contentious energy sources in the modern world, representing both tremendous promise and considerable challenges in humanity's quest for sustainable electricity generation. At its core, nuclear power harnesses the immense energy released through nuclear fission—the splitting of atomic nuclei—to generate heat that drives turbines and produces electricity on a massive scale. This process, first demonstrated in controlled form during the Manhattan Project in the 1940s, has since evolved into a sophisticated technology that currently provides approximately ten to eleven percent of the world's electricity supply, making it a crucial component of the global energy infrastructure. The fundamental principle underlying nuclear power is elegantly simple yet profoundly powerful: when a heavy nucleus such as uranium-235 or plutonium-239 is struck by a neutron, it splits into lighter elements, releasing tremendous amounts of energy in the form of heat, radiation, and kinetic energy of the resulting fragments. This energy release is governed by Einstein's famous equation E=mc², which demonstrates that even tiny amounts of mass can be converted into enormous quantities of energy, making nuclear reactions exponentially more efficient than chemical combustion processes used in fossil fuel power plants.
#
# The operational mechanics of a nuclear power plant involve several interconnected systems working in concert to safely convert nuclear energy into usable electricity. Within the reactor core, uranium fuel assemblies undergo controlled fission reactions, with control rods inserted between fuel elements to absorb excess neutrons and regulate the reaction rate, preventing dangerous runaway reactions. The intense heat generated by fission is transferred to a coolant—typically water—which circulates through the reactor core, absorbing thermal energy and preventing the fuel from overheating. This heated coolant then transfers its thermal energy to secondary systems, where steam is generated and directed through turbines connected to electrical generators, following the same basic thermodynamic principles used in conventional power plants but with a nuclear heat source instead of fossil fuel combustion. The steam, after passing through the turbines, is condensed back into water using cooling towers or other cooling systems, and the cycle repeats continuously. This elegant system has proven remarkably reliable and efficient, with modern nuclear plants achieving capacity factors—the ratio of actual output to theoretical maximum output—often exceeding ninety percent, substantially higher than most renewable energy sources and competitive with fossil fuel plants.
#
# The advantages of nuclear power are substantial and multifaceted, making it an attractive option for energy planners and climate-conscious policymakers worldwide. Most prominently, nuclear power produces virtually no greenhouse gas emissions during operation, with lifecycle emissions comparable to wind and solar energy when accounting for construction, decommissioning, and fuel processing. This characteristic makes nuclear power an invaluable tool in combating climate change and meeting international carbon reduction targets, particularly as nations worldwide commit to net-zero emissions by mid-century. Furthermore, nuclear power plants occupy remarkably small physical footprints compared to renewable energy sources; a single nuclear facility can generate as much electricity as vast solar farms or wind installations spanning hundreds of square kilometers, making nuclear power exceptionally land-efficient—a critical consideration in densely populated regions where available land is limited. The energy density of nuclear fuel is extraordinary; a single uranium pellet the size of a fingertip contains as much energy as a ton of coal or three barrels of oil, meaning that nuclear fuel transportation and storage requirements are minimal compared to fossil fuels. Additionally, nuclear power provides reliable baseload electricity generation, operating continuously regardless of weather conditions, time of day, or seasonal variations, unlike intermittent renewable sources that depend on wind and sunlight availability. This reliability makes nuclear power particularly valuable for maintaining grid stability and meeting consistent electricity demand in modern industrial societies.
#
# However, nuclear power faces significant challenges and legitimate concerns that have shaped public perception and policy decisions across the globe. The question of radioactive waste disposal remains perhaps the most persistent and troubling issue; nuclear reactors generate spent fuel that remains dangerously radioactive for thousands of years, requiring secure storage solutions that must remain isolated from the environment for timescales that exceed human civilization's entire recorded history. While various disposal strategies have been proposed—including deep geological repositories, transmutation of long-lived isotopes, and advanced reactor designs that can utilize existing waste—no permanent, universally accepted solution has been implemented in most countries, leaving accumulating stockpiles of spent fuel stored at reactor sites or temporary facilities. The catastrophic accidents at Chernobyl in 1986 and Fukushima Daiichi in 2011 have profoundly influenced public perception of nuclear safety, demonstrating that even with multiple redundant safety systems, extreme circumstances can overwhelm protective measures and result in widespread contamination and long-term environmental damage. The Chernobyl disaster, resulting from a catastrophic safety test gone wrong, rendered an area of approximately thirty kilometers around the reactor essentially uninhabitable and caused immediate deaths, long-term health effects, and environmental contamination that persists decades later. The Fukushima accident, triggered by a massive earthquake and tsunami that disabled cooling systems, resulted in three reactor meltdowns and the evacuation of approximately 154,000 residents, demonstrating that even modern plants in technologically advanced nations remain vulnerable to extraordinary natural disasters. These incidents, while statistically rare, have created deep public anxiety about nuclear safety and contributed to political opposition to nuclear expansion in many countries.
#
# The economic dimensions of nuclear power present another complex landscape of considerations. Constructing a modern nuclear power plant requires enormous capital investments, often exceeding ten to twenty billion dollars, with lengthy construction timelines frequently extending a decade or more, during which costs can escalate significantly due to regulatory changes, design modifications, and inflation. These substantial upfront costs create significant financial barriers to nuclear development, particularly in developing nations with limited capital resources, and the long payback periods mean that nuclear projects require stable, long-term policy commitments and financing mechanisms that can be difficult to secure in politically volatile environments. Conversely, once constructed, nuclear plants operate with relatively low fuel and maintenance costs, and their high capacity factors mean that the per-unit cost of electricity generated over the plant's operational lifetime can be competitive with other energy sources, particularly when carbon pricing mechanisms are implemented that penalize greenhouse gas emissions. The decommissioning of aging nuclear plants also presents substantial costs, as reactors become radioactive and must be carefully dismantled and the site remediated, with decommissioning costs sometimes rivaling initial construction expenses.
#
# Looking toward the future, nuclear power technology continues to evolve with promising developments that could address current limitations. Generation IV reactor designs, including fast breeder reactors, molten salt reactors, and high-temperature gas reactors, promise enhanced safety features, improved fuel efficiency, and reduced waste production compared to current light-water reactor designs. Small modular reactors (SMRs) represent another frontier, offering the potential for flexible deployment in smaller grids, remote locations, and industrial heat applications, though their economic viability at commercial scale remains unproven. Advanced fuel cycles and transmutation technologies could potentially reduce the long-term radiotoxicity of nuclear waste, though these technologies remain largely in development stages. Ultimately, nuclear power's role in the future energy landscape will depend on technological progress, policy decisions, public acceptance, and how effectively it integrates with renewable energy sources and energy storage systems in a diversified, resilient energy infrastructure designed to meet humanity's electricity needs while minimizing environmental impact and ensuring long-term sustainability.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)
# Out:
# The grading function in this cell is looking for a response that is equal to or greater than 800 words.
# Because LLMs aren't great at counting words yet, you may have to overshoot your target.

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
